# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from  sklearn.cluster import DBSCAN

# %%
two_blob=pd.read_csv('C:/SINGH/Data/cluster_two_blobs.csv')

# %%
two_blobs_outliers=pd.read_csv('C:/SINGH/Data/cluster_two_blobs_outliers.csv')

# %%
two_blob
# Out:
#             X1        X2
# 0     4.645333  6.822294
# 1     4.784032  6.422883
# 2    -5.851786  5.774331
# 3    -7.459592  6.456415
# 4     4.918911  6.961479
# ...        ...       ...
# 1495  0.882673 -6.786272
# 1496  0.946854 -7.254512
# 1497  3.180138  6.608660
# 1498  5.454552  6.461246
# 1499 -7.769230  7.014384
#
# [1500 rows x 2 columns]

# %%
sns.scatterplot(data=two_blob,x='X1',y='X2')
# Out:
# <AxesSubplot:xlabel='X1', ylabel='X2'>

# %%
sns.scatterplot(data=two_blobs_outliers,x='X1',y='X2')
# Out:
# <AxesSubplot:xlabel='X1', ylabel='X2'>

# %%
def display_categories(model,data):
    labels=model.fit_predict(data)
    sns.scatterplot(data=data,x='X1',y='X2',hue=labels,palette='Set1')

# %%
model=DBSCAN()

# %%
display_categories(model,two_blob)

# %%
display_categories(model,two_blobs_outliers)

# %%
dbscan= DBSCAN(eps=1)

# %%
display_categories(dbscan,two_blobs_outliers)

# %%
np.sum(dbscan.labels_== -1) ''' IT will give no of outliers '''
# Out:
# 3

# %%
dbscan.labels_
# Out:
# array([ 0,  1,  0, ..., -1, -1, -1], dtype=int64)

# %%
100*np.sum(dbscan.labels_== -1)/len(dbscan.labels_)
# Out:
# 0.29910269192422734

# %%
len(dbscan.labels_)
# Out:
# 1003

# %%
len(two_blobs_outliers)
# Out:
# 1003
